# %% [markdown]
# Import Libraries
# These are essential Python libraries for data analysis and visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional for better visualization aesthetics
sns.set(style='whitegrid')

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\AI & ML INTERNSHIP\day2\Titanic-Dataset.csv") #reads the dataset.
df.head() #displays the first few rows.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
#  Basic Information & Null Values
#
# info() shows data types and missing values.
#
# isnull().sum() counts missing values per column.

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %% [markdown]
# Descriptive Statistics
#
# Gives statistical overview: mean, std dev, min, max, percentiles — for numerical features only.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Data Cleaning

# %%
# Fill Age with median, drop Cabin, fill Embarked with mode
df['Age'].fillna(df['Age'].median())
df['Embarked'].fillna(df['Embarked'].mode()[0])
df.drop(columns='Cabin', inplace=True)

# %% [markdown]
# Univariate Analysis
#
# 1.Histogram & Boxplot
#
# Helps spot outliers (boxplots) and shape/skew of distribution (histogram).

# %%
numeric_features = df.select_dtypes(include=np.number).columns.tolist()

# %%
for feature in numeric_features:
    plt.figure(figsize=(12,4))
    
    plt.subplot(1, 2, 1)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[feature])
    plt.title(f'Boxplot of {feature}')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Categorical Features Analysis

# %%
sns.barplot(x='Pclass', y='Fare', data=df)
plt.title("Average Fare by Passenger Class")
plt.show()

# %%
categorical = df.select_dtypes(include='object').columns.tolist()

for feature in categorical:
    plt.figure(figsize=(6,4))
    sns.countplot(x=df[feature])
    plt.title(f'Countplot of {feature}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Bivariate Analysis
# 🔹 Survival Rate by Gender and Class

# %%
sns.countplot(x='Survived', hue='Sex', data=df)
plt.title('Survival Count by Gender')
plt.show()

sns.countplot(x='Survived', hue='Pclass', data=df)
plt.title('Survival Count by Passenger Class')
plt.show()

# %% [markdown]
# Correlation Analysis
#
# Shows relationship between numerical variables.
#
# Values close to +1 or -1 = strong correlation.

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Pairplot for Detailed Relations
#
# Visualizes scatter relationships, colored by survival.

# %%
selected = ['Age', 'Fare', 'Pclass', 'Survived']
sns.pairplot(df[selected], hue='Survived')

# %% [markdown]
# Detecting Skewness
#
# Skewness > 1 or < -1 suggests high skew; transformations might help.

# %%
df[numeric_features].skew()
# Out:
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.389108
# SibSp          3.695352
# Parch          2.749117
# Fare           4.787317
# dtype: float64
